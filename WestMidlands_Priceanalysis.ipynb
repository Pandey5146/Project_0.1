# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Enable inline plotting
# %matplotlib inline

# %%
# Load the data from CSV file
file_path = "C:\\Users\\96cra\\OneDrive\\Documents\\csv_agile_E_West_Midlands1.csv"
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
df.head()
# Out:
#                         Date   Time  E            Loc      Gen
# 0  2018-02-21 00:00:00+00:00  00:00  E  West_Midlands  10.3425
# 1  2018-02-21 00:30:00+00:00  00:30  E  West_Midlands  10.5735
# 2  2018-02-21 01:00:00+00:00  01:00  E  West_Midlands  10.6680
# 3  2018-02-21 01:30:00+00:00  01:30  E  West_Midlands  10.1850
# 4  2018-02-21 02:00:00+00:00  02:00  E  West_Midlands  10.1430

# %%
data = pd.read_csv(file_path)

# %%
# Ensure 'Date' column is of datetime type
data['Date'] = pd.to_datetime(data['Date'])

# %%
# Set 'Date' as the index
data.set_index('Date', inplace=True)

# %%
# Display the first few rows of the dataframe
print(data.head())
# Out:
#                             Time  E            Loc      Gen
# Date
# 2018-02-21 00:00:00+00:00  00:00  E  West_Midlands  10.3425
# 2018-02-21 00:30:00+00:00  00:30  E  West_Midlands  10.5735
# 2018-02-21 01:00:00+00:00  01:00  E  West_Midlands  10.6680
# 2018-02-21 01:30:00+00:00  01:30  E  West_Midlands  10.1850
# 2018-02-21 02:00:00+00:00  02:00  E  West_Midlands  10.1430

# %%
# Basic statistics
print("Basic Statistics:")
print(data['Gen'].describe())

# Plotting the price over time
#Gen = Price
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Gen'], label='Gen')
plt.xlabel('Date')
plt.ylabel('Gen')
plt.title('Electricity Gen Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Basic Statistics:
# count    111456.000000
# mean         19.168033
# std          12.482859
# min         -19.026000
# 25%           9.901500
# 50%          15.435000
# 75%          27.520500
# max          82.143285
# Name: Gen, dtype: float64
